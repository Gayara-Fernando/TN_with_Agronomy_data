# %%
# import the necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import random
import shutil
# import cv2
from scipy import ndimage
# from skimage.transform import resize
from joblib import Parallel, delayed
import tensorflow as tf
from sklearn.model_selection import KFold
# from tqdm.notebook import tqdm
# Out:
# 2022-11-30 14:34:44.923937: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
tf.config.list_physical_devices ('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# First do the data pre-processing, and store the data so that they can be used later if needed

# %%
# load the numpy files of the images and the sub image counts

# data files
all_train_sub_images = np.load(r"/work/statsgeneral/gayara/Filtered_90/Data_files/all_sub_windows_float16.npy")

# %%
all_train_sub_images.shape
# Out:
# (1347113, 32, 32, 3)

# %%
all_train_sub_images_counts = np.load(r"/work/statsgeneral/gayara/Filtered_90/Data_files/all_sub_windows_counts_float16.npy")

# %%
all_train_sub_images_counts.shape
# Out:
# (1347113,)

# %%
# generate a random sample based on a sequence

# fix the seed
random.seed(32)
# random numbers for validation data
rand_digits_for_validation = random.sample(range(len(all_train_sub_images)),67356)

# all data
rand_all_available = random.sample(range(len(all_train_sub_images)),len(all_train_sub_images))

# %%
# random numbers for train data
train_indices_all = set(rand_all_available) - set(rand_digits_for_validation)

# %%
# Get the validation data and the y labels
X_valid_list = [all_train_sub_images[idx] for idx in rand_digits_for_validation]
y_valid_list = [all_train_sub_images_counts[idx] for idx in rand_digits_for_validation]

# %%
# stack these to pass into the model
X_valid = np.stack(X_valid_list)
y_valid = np.stack(y_valid_list)

# %%
# get everything else as tran data, but later do the bootstraps from these data only.
X_train_all_list = [all_train_sub_images[idx] for idx in train_indices_all]
y_train_all_list = [all_train_sub_images_counts[idx] for idx in train_indices_all]

# %%
X_train_all = np.stack(X_train_all_list)
y_train_all = np.stack(y_train_all_list)

# %%
X_train_all.shape
# Out:
# (1279757, 32, 32, 3)

# %%
def train_bootstrap(image_values, counts):
    train_index = random.sample(range(len(image_values)),269423)
    
    train_X_list = [image_values[idx] for idx in train_index]
    train_X = np.stack(train_X_list)
    train_y_list = [counts[idx] for idx in train_index]
    train_y = np.stack(train_y_list)
    return(train_X, train_y)

# %%
# Do this in a loop 5 times to get the train X, and y values
X_train_all_final = []
y_train_all_final = []
for i in range(5):
    retuned_vals = train_bootstrap(X_train_all, y_train_all)
    X_train_all_final.append(retuned_vals[0])
    y_train_all_final.append(retuned_vals[1])

# %%
# need to introduce a counter for saving the models
counter = 96
for i in range(len(X_train_all_final)):
    X_train = X_train_all_final[i]
    y_train = y_train_all_final[i]
    tf.keras.backend.clear_session()
    # load the pre-trained model on tassels
    model = tf.keras.models.load_model('/home/statsgeneral/gayara/Tasselnet/Filtered_90/tasselnet1_overlapping_w32.h5')
    # look at the input shape
    model.input
    
    # need to remove some of the last layers
    output_trial = model.layers[-8].output
    
    # create the functional API model
    reduced_model = tf.keras.models.Model(model.input, output_trial)
    
    # okay, now need to add back the dropout, the dense and activation

    # add dropout
    added_dropout = tf.keras.layers.Dropout(0.5, name = "New_dropout")(model.layers[-8].output)

    # add flatten
    added_flatten = tf.keras.layers.Flatten(name = "Flatten2")(added_dropout)

    # add dense
    added_dense = tf.keras.layers.Dense(512, name = "New_Dense")(added_flatten)

    # add activation
    added_Act = tf.keras.layers.Activation('relu', name = "New_Activation")(added_dense)

    # add dropout
    added_dropout2 = tf.keras.layers.Dropout(0.5, name = "New_dropout2")(added_Act)

    # add dense
    added_dense2 = tf.keras.layers.Dense(1, name = "New_Dense2")(added_dropout2)

    # add activation
    added_Act2 = tf.keras.layers.Activation('relu', name = "New_Activation2")(added_dense2)
    
    # define the new model with functional API
    new_model = tf.keras.models.Model(model.input, added_Act2)
    
    #     freeze layers
    for layer in model.layers:
        layer.trainable = False
    
    # compile the model
    opt = tf.keras.optimizers.Adam(learning_rate=0.0001)
    new_model.compile(loss='mean_squared_error', optimizer=opt, metrics = ['mean_absolute_error'])
    
    # add early stopping
    es = tf.keras.callbacks.EarlyStopping(monitor='val_loss', restore_best_weights = True, verbose=1, patience=5)
    
    #     fit the frozen model
    history = new_model.fit(X_train, y_train,
          epochs = 50, callbacks = [es],
          validation_data = (X_valid, y_valid), 
                       batch_size = 2000, validation_batch_size = 2000)
    
    
    # # unfreeze few layers and retrain
    model.trainable = True

    set_trainable = False

    for layer in model.layers:
        if layer.name == 'conv2d_3':
            set_trainable = True
        if set_trainable:
            layer.trainable = True
        else:
            layer.trainable = False
            
    # # compile the mdoel
    opt = tf.keras.optimizers.Adam(learning_rate=0.0001)
    new_model.compile(loss='mean_squared_error', optimizer=opt, metrics = ['mean_absolute_error'])
    
    # # add early stopping
    es = tf.keras.callbacks.EarlyStopping(monitor='val_loss', restore_best_weights = True, verbose=1, patience=5)
    
    # # fit the model (fine tuned)
    history_new = new_model.fit(X_train, y_train,
          epochs = 50, callbacks = [es],
          validation_data = (X_valid, y_valid), 
                       batch_size = 2000, validation_batch_size = 2000)
    
    #     save the model
    model_name = 'model_bootstrap' + str(counter) + '.h5'
    counter = counter + 1
    path = "/home/statsgeneral/gayara/Tasselnet/Filtered_90/models" + "/" + model_name
    new_model.save(path)
# Out:
# 2022-11-30 14:35:08.469040: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-11-30 14:35:08.983400: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 30965 MB memory:  -> device: 0, name: Tesla V100-PCIE-32GB, pci bus id: 0000:5e:00.0, compute capability: 7.0
# Epoch 1/50
# 2022-11-30 14:35:15.059073: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8401
# 2022-11-30 14:35:15.593472: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2022-11-30 14:35:15.594012: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2022-11-30 14:35:15.594026: W tensorflow/stream_executor/gpu/asm_compiler.cc:80] Couldn't get ptxas version string: INTERNAL: Couldn't invoke ptxas --version
# 2022-11-30 14:35:15.594333: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2022-11-30 14:35:15.594381: W tensorflow/stream_executor/gpu/redzone_allocator.cc:314] INTERNAL: Failed to launch ptxas
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.
# 135/135 [==============================] - 7s 39ms/step - loss: 0.0356 - mean_absolute_error: 0.1009 - val_loss: 0.0312 - val_mean_absolute_error: 0.0925
# Epoch 2/50
# 135/135 [==============================] - 3s 23ms/step - loss: 0.0322 - mean_absolute_error: 0.0972 - val_loss: 0.0316 - val_mean_absolute_error: 0.0923
# Epoch 3/50
# 135/135 [==============================] - 3s 23ms/step - loss: 0.0314 - mean_absolute_error: 0.0975 - val_loss: 0.0324 - val_mean_absolute_error: 0.0920
# Epoch 4/50
# 135/135 [==============================] - 3s 23ms/step - loss: 0.0309 - mean_absolute_error: 0.0976 - val_loss: 0.0326 - val_mean_absolute_error: 0.0925
# Epoch 5/50
# 135/135 [==============================] - 3s 23ms/step - loss: 0.0307 - mean_absolute_error: 0.0980 - val_loss: 0.0328 - val_mean_absolute_error: 0.0953
# Epoch 6/50
# 133/135 [============================>.] - ETA: 0s - loss: 0.0305 - mean_absolute_error: 0.0985Restoring model weights from the end of the best epoch: 1.
# 135/135 [==============================] - 3s 23ms/step - loss: 0.0305 - mean_absolute_error: 0.0985 - val_loss: 0.0324 - val_mean_absolute_error: 0.0963
# Epoch 6: early stopping
# Epoch 1/50
# 135/135 [==============================] - 6s 37ms/step - loss: 0.0311 - mean_absolute_error: 0.0967 - val_loss: 0.0294 - val_mean_absolute_error: 0.0967
# Epoch 2/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0294 - mean_absolute_error: 0.0962 - val_loss: 0.0290 - val_mean_absolute_error: 0.0951
# Epoch 3/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0286 - mean_absolute_error: 0.0955 - val_loss: 0.0284 - val_mean_absolute_error: 0.0934
# Epoch 4/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0281 - mean_absolute_error: 0.0946 - val_loss: 0.0284 - val_mean_absolute_error: 0.0934
# Epoch 5/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0277 - mean_absolute_error: 0.0941 - val_loss: 0.0275 - val_mean_absolute_error: 0.0946
# Epoch 6/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0276 - mean_absolute_error: 0.0937 - val_loss: 0.0277 - val_mean_absolute_error: 0.0918
# Epoch 7/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0272 - mean_absolute_error: 0.0926 - val_loss: 0.0272 - val_mean_absolute_error: 0.0938
# Epoch 8/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0271 - mean_absolute_error: 0.0927 - val_loss: 0.0272 - val_mean_absolute_error: 0.0926
# Epoch 9/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0268 - mean_absolute_error: 0.0919 - val_loss: 0.0273 - val_mean_absolute_error: 0.0908
# Epoch 10/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0267 - mean_absolute_error: 0.0916 - val_loss: 0.0268 - val_mean_absolute_error: 0.0921
# Epoch 11/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0266 - mean_absolute_error: 0.0909 - val_loss: 0.0267 - val_mean_absolute_error: 0.0906
# Epoch 12/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0264 - mean_absolute_error: 0.0904 - val_loss: 0.0268 - val_mean_absolute_error: 0.0915
# Epoch 13/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0263 - mean_absolute_error: 0.0905 - val_loss: 0.0265 - val_mean_absolute_error: 0.0905
# Epoch 14/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0262 - mean_absolute_error: 0.0900 - val_loss: 0.0262 - val_mean_absolute_error: 0.0908
# Epoch 15/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0260 - mean_absolute_error: 0.0895 - val_loss: 0.0258 - val_mean_absolute_error: 0.0936
# Epoch 16/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0259 - mean_absolute_error: 0.0893 - val_loss: 0.0262 - val_mean_absolute_error: 0.0896
# Epoch 17/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0257 - mean_absolute_error: 0.0890 - val_loss: 0.0259 - val_mean_absolute_error: 0.0899
# Epoch 18/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0256 - mean_absolute_error: 0.0884 - val_loss: 0.0258 - val_mean_absolute_error: 0.0896
# Epoch 19/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0255 - mean_absolute_error: 0.0882 - val_loss: 0.0255 - val_mean_absolute_error: 0.0896
# Epoch 20/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0254 - mean_absolute_error: 0.0880 - val_loss: 0.0255 - val_mean_absolute_error: 0.0889
# Epoch 21/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0253 - mean_absolute_error: 0.0878 - val_loss: 0.0255 - val_mean_absolute_error: 0.0883
# Epoch 22/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0252 - mean_absolute_error: 0.0874 - val_loss: 0.0253 - val_mean_absolute_error: 0.0890
# Epoch 23/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0251 - mean_absolute_error: 0.0874 - val_loss: 0.0250 - val_mean_absolute_error: 0.0889
# Epoch 24/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0250 - mean_absolute_error: 0.0871 - val_loss: 0.0249 - val_mean_absolute_error: 0.0893
# Epoch 25/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0249 - mean_absolute_error: 0.0867 - val_loss: 0.0247 - val_mean_absolute_error: 0.0891
# Epoch 26/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0248 - mean_absolute_error: 0.0865 - val_loss: 0.0250 - val_mean_absolute_error: 0.0883
# Epoch 27/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0247 - mean_absolute_error: 0.0863 - val_loss: 0.0248 - val_mean_absolute_error: 0.0864
# Epoch 28/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0246 - mean_absolute_error: 0.0860 - val_loss: 0.0247 - val_mean_absolute_error: 0.0884
# Epoch 29/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0245 - mean_absolute_error: 0.0858 - val_loss: 0.0246 - val_mean_absolute_error: 0.0881
# Epoch 30/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0245 - mean_absolute_error: 0.0859 - val_loss: 0.0245 - val_mean_absolute_error: 0.0876
# Epoch 31/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0244 - mean_absolute_error: 0.0854 - val_loss: 0.0245 - val_mean_absolute_error: 0.0873
# Epoch 32/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0244 - mean_absolute_error: 0.0854 - val_loss: 0.0243 - val_mean_absolute_error: 0.0866
# Epoch 33/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0243 - mean_absolute_error: 0.0850 - val_loss: 0.0243 - val_mean_absolute_error: 0.0880
# Epoch 34/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0243 - mean_absolute_error: 0.0852 - val_loss: 0.0242 - val_mean_absolute_error: 0.0876
# Epoch 35/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0241 - mean_absolute_error: 0.0847 - val_loss: 0.0241 - val_mean_absolute_error: 0.0881
# Epoch 36/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0241 - mean_absolute_error: 0.0847 - val_loss: 0.0240 - val_mean_absolute_error: 0.0871
# Epoch 37/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0241 - mean_absolute_error: 0.0848 - val_loss: 0.0239 - val_mean_absolute_error: 0.0879
# Epoch 38/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0239 - mean_absolute_error: 0.0843 - val_loss: 0.0240 - val_mean_absolute_error: 0.0871
# Epoch 39/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0239 - mean_absolute_error: 0.0843 - val_loss: 0.0239 - val_mean_absolute_error: 0.0872
# Epoch 40/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0238 - mean_absolute_error: 0.0840 - val_loss: 0.0239 - val_mean_absolute_error: 0.0871
# Epoch 41/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0238 - mean_absolute_error: 0.0840 - val_loss: 0.0239 - val_mean_absolute_error: 0.0867
# Epoch 42/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0238 - mean_absolute_error: 0.0837 - val_loss: 0.0240 - val_mean_absolute_error: 0.0843
# Epoch 43/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0236 - mean_absolute_error: 0.0834 - val_loss: 0.0238 - val_mean_absolute_error: 0.0858
# Epoch 44/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0236 - mean_absolute_error: 0.0832 - val_loss: 0.0237 - val_mean_absolute_error: 0.0852
# Epoch 45/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0236 - mean_absolute_error: 0.0833 - val_loss: 0.0238 - val_mean_absolute_error: 0.0864
# Epoch 46/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0235 - mean_absolute_error: 0.0830 - val_loss: 0.0236 - val_mean_absolute_error: 0.0863
# Epoch 47/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0235 - mean_absolute_error: 0.0829 - val_loss: 0.0236 - val_mean_absolute_error: 0.0895
# Epoch 48/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0234 - mean_absolute_error: 0.0827 - val_loss: 0.0235 - val_mean_absolute_error: 0.0853
# Epoch 49/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0234 - mean_absolute_error: 0.0827 - val_loss: 0.0234 - val_mean_absolute_error: 0.0875
# Epoch 50/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0233 - mean_absolute_error: 0.0825 - val_loss: 0.0235 - val_mean_absolute_error: 0.0850
# Epoch 1/50
# 135/135 [==============================] - 5s 33ms/step - loss: 0.0363 - mean_absolute_error: 0.1018 - val_loss: 0.0316 - val_mean_absolute_error: 0.0932
# Epoch 2/50
# 135/135 [==============================] - 3s 23ms/step - loss: 0.0324 - mean_absolute_error: 0.0978 - val_loss: 0.0319 - val_mean_absolute_error: 0.0932
# Epoch 3/50
# 135/135 [==============================] - 3s 23ms/step - loss: 0.0316 - mean_absolute_error: 0.0976 - val_loss: 0.0323 - val_mean_absolute_error: 0.0938
# Epoch 4/50
# 135/135 [==============================] - 3s 23ms/step - loss: 0.0312 - mean_absolute_error: 0.0982 - val_loss: 0.0326 - val_mean_absolute_error: 0.0936
# Epoch 5/50
# 135/135 [==============================] - 3s 23ms/step - loss: 0.0309 - mean_absolute_error: 0.0985 - val_loss: 0.0321 - val_mean_absolute_error: 0.0958
# Epoch 6/50
# 133/135 [============================>.] - ETA: 0s - loss: 0.0307 - mean_absolute_error: 0.0985Restoring model weights from the end of the best epoch: 1.
# 135/135 [==============================] - 3s 23ms/step - loss: 0.0307 - mean_absolute_error: 0.0985 - val_loss: 0.0320 - val_mean_absolute_error: 0.0978
# Epoch 6: early stopping
# Epoch 1/50
# 135/135 [==============================] - 5s 35ms/step - loss: 0.0313 - mean_absolute_error: 0.0976 - val_loss: 0.0302 - val_mean_absolute_error: 0.0957
# Epoch 2/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0295 - mean_absolute_error: 0.0973 - val_loss: 0.0288 - val_mean_absolute_error: 0.0971
# Epoch 3/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0288 - mean_absolute_error: 0.0965 - val_loss: 0.0286 - val_mean_absolute_error: 0.0958
# Epoch 4/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0284 - mean_absolute_error: 0.0955 - val_loss: 0.0283 - val_mean_absolute_error: 0.0945
# Epoch 5/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0281 - mean_absolute_error: 0.0950 - val_loss: 0.0280 - val_mean_absolute_error: 0.0945
# Epoch 6/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0278 - mean_absolute_error: 0.0943 - val_loss: 0.0275 - val_mean_absolute_error: 0.0945
# Epoch 7/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0276 - mean_absolute_error: 0.0939 - val_loss: 0.0275 - val_mean_absolute_error: 0.0936
# Epoch 8/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0273 - mean_absolute_error: 0.0932 - val_loss: 0.0277 - val_mean_absolute_error: 0.0922
# Epoch 9/50
# 135/135 [==============================] - 4s 26ms/step - loss: 0.0272 - mean_absolute_error: 0.0930 - val_loss: 0.0272 - val_mean_absolute_error: 0.0920
# Epoch 10/50
# 135/135 [==============================] - 4s 26ms/step - loss: 0.0270 - mean_absolute_error: 0.0924 - val_loss: 0.0274 - val_mean_absolute_error: 0.0906
# Epoch 11/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0269 - mean_absolute_error: 0.0919 - val_loss: 0.0266 - val_mean_absolute_error: 0.0927
# Epoch 12/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0267 - mean_absolute_error: 0.0916 - val_loss: 0.0264 - val_mean_absolute_error: 0.0927
# Epoch 13/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0265 - mean_absolute_error: 0.0911 - val_loss: 0.0267 - val_mean_absolute_error: 0.0911
# Epoch 14/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0264 - mean_absolute_error: 0.0907 - val_loss: 0.0262 - val_mean_absolute_error: 0.0922
# Epoch 15/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0263 - mean_absolute_error: 0.0903 - val_loss: 0.0263 - val_mean_absolute_error: 0.0923
# Epoch 16/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0261 - mean_absolute_error: 0.0902 - val_loss: 0.0260 - val_mean_absolute_error: 0.0915
# Epoch 17/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0259 - mean_absolute_error: 0.0897 - val_loss: 0.0260 - val_mean_absolute_error: 0.0899
# Epoch 18/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0258 - mean_absolute_error: 0.0893 - val_loss: 0.0257 - val_mean_absolute_error: 0.0906
# Epoch 19/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0258 - mean_absolute_error: 0.0892 - val_loss: 0.0257 - val_mean_absolute_error: 0.0910
# Epoch 20/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0256 - mean_absolute_error: 0.0887 - val_loss: 0.0254 - val_mean_absolute_error: 0.0908
# Epoch 21/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0255 - mean_absolute_error: 0.0886 - val_loss: 0.0254 - val_mean_absolute_error: 0.0898
# Epoch 22/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0254 - mean_absolute_error: 0.0883 - val_loss: 0.0253 - val_mean_absolute_error: 0.0896
# Epoch 23/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0253 - mean_absolute_error: 0.0879 - val_loss: 0.0250 - val_mean_absolute_error: 0.0912
# Epoch 24/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0252 - mean_absolute_error: 0.0878 - val_loss: 0.0251 - val_mean_absolute_error: 0.0888
# Epoch 25/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0250 - mean_absolute_error: 0.0873 - val_loss: 0.0250 - val_mean_absolute_error: 0.0880
# Epoch 26/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0250 - mean_absolute_error: 0.0873 - val_loss: 0.0248 - val_mean_absolute_error: 0.0884
# Epoch 27/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0249 - mean_absolute_error: 0.0868 - val_loss: 0.0249 - val_mean_absolute_error: 0.0879
# Epoch 28/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0249 - mean_absolute_error: 0.0867 - val_loss: 0.0249 - val_mean_absolute_error: 0.0874
# Epoch 29/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0249 - mean_absolute_error: 0.0868 - val_loss: 0.0245 - val_mean_absolute_error: 0.0896
# Epoch 30/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0247 - mean_absolute_error: 0.0861 - val_loss: 0.0247 - val_mean_absolute_error: 0.0881
# Epoch 31/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0246 - mean_absolute_error: 0.0860 - val_loss: 0.0245 - val_mean_absolute_error: 0.0884
# Epoch 32/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0246 - mean_absolute_error: 0.0858 - val_loss: 0.0244 - val_mean_absolute_error: 0.0878
# Epoch 33/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0245 - mean_absolute_error: 0.0859 - val_loss: 0.0243 - val_mean_absolute_error: 0.0890
# Epoch 34/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0244 - mean_absolute_error: 0.0856 - val_loss: 0.0243 - val_mean_absolute_error: 0.0881
# Epoch 35/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0243 - mean_absolute_error: 0.0854 - val_loss: 0.0241 - val_mean_absolute_error: 0.0890
# Epoch 36/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0243 - mean_absolute_error: 0.0850 - val_loss: 0.0241 - val_mean_absolute_error: 0.0874
# Epoch 37/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0242 - mean_absolute_error: 0.0849 - val_loss: 0.0240 - val_mean_absolute_error: 0.0872
# Epoch 38/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0242 - mean_absolute_error: 0.0846 - val_loss: 0.0240 - val_mean_absolute_error: 0.0891
# Epoch 39/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0241 - mean_absolute_error: 0.0847 - val_loss: 0.0239 - val_mean_absolute_error: 0.0869
# Epoch 40/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0241 - mean_absolute_error: 0.0845 - val_loss: 0.0239 - val_mean_absolute_error: 0.0884
# Epoch 41/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0240 - mean_absolute_error: 0.0843 - val_loss: 0.0239 - val_mean_absolute_error: 0.0881
# Epoch 42/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0239 - mean_absolute_error: 0.0842 - val_loss: 0.0238 - val_mean_absolute_error: 0.0864
# Epoch 43/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0239 - mean_absolute_error: 0.0840 - val_loss: 0.0237 - val_mean_absolute_error: 0.0864
# Epoch 44/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0237 - mean_absolute_error: 0.0837 - val_loss: 0.0238 - val_mean_absolute_error: 0.0857
# Epoch 45/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0237 - mean_absolute_error: 0.0836 - val_loss: 0.0238 - val_mean_absolute_error: 0.0867
# Epoch 46/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0237 - mean_absolute_error: 0.0835 - val_loss: 0.0238 - val_mean_absolute_error: 0.0849
# Epoch 47/50
# 135/135 [==============================] - 4s 26ms/step - loss: 0.0236 - mean_absolute_error: 0.0834 - val_loss: 0.0236 - val_mean_absolute_error: 0.0872
# Epoch 48/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0236 - mean_absolute_error: 0.0833 - val_loss: 0.0236 - val_mean_absolute_error: 0.0869
# Epoch 49/50
# 135/135 [==============================] - 4s 26ms/step - loss: 0.0236 - mean_absolute_error: 0.0833 - val_loss: 0.0235 - val_mean_absolute_error: 0.0855
# Epoch 50/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0235 - mean_absolute_error: 0.0828 - val_loss: 0.0235 - val_mean_absolute_error: 0.0873
# Epoch 1/50
# 135/135 [==============================] - 5s 32ms/step - loss: 0.0356 - mean_absolute_error: 0.1021 - val_loss: 0.0320 - val_mean_absolute_error: 0.0930
# Epoch 2/50
# 135/135 [==============================] - 3s 23ms/step - loss: 0.0327 - mean_absolute_error: 0.0989 - val_loss: 0.0323 - val_mean_absolute_error: 0.0929
# Epoch 3/50
# 135/135 [==============================] - 3s 23ms/step - loss: 0.0318 - mean_absolute_error: 0.0988 - val_loss: 0.0324 - val_mean_absolute_error: 0.0931
# Epoch 4/50
# 135/135 [==============================] - 3s 23ms/step - loss: 0.0314 - mean_absolute_error: 0.0994 - val_loss: 0.0320 - val_mean_absolute_error: 0.0945
# Epoch 5/50
# 135/135 [==============================] - 3s 23ms/step - loss: 0.0311 - mean_absolute_error: 0.0995 - val_loss: 0.0323 - val_mean_absolute_error: 0.0958
# Epoch 6/50
# 133/135 [============================>.] - ETA: 0s - loss: 0.0310 - mean_absolute_error: 0.0994Restoring model weights from the end of the best epoch: 1.
# 135/135 [==============================] - 3s 23ms/step - loss: 0.0309 - mean_absolute_error: 0.0994 - val_loss: 0.0322 - val_mean_absolute_error: 0.0982
# Epoch 6: early stopping
# Epoch 1/50
# 135/135 [==============================] - 5s 35ms/step - loss: 0.0314 - mean_absolute_error: 0.0982 - val_loss: 0.0301 - val_mean_absolute_error: 0.0961
# Epoch 2/50
# 135/135 [==============================] - 4s 26ms/step - loss: 0.0298 - mean_absolute_error: 0.0974 - val_loss: 0.0291 - val_mean_absolute_error: 0.0957
# Epoch 3/50
# 135/135 [==============================] - 3s 26ms/step - loss: 0.0291 - mean_absolute_error: 0.0967 - val_loss: 0.0285 - val_mean_absolute_error: 0.0960
# Epoch 4/50
# 135/135 [==============================] - 4s 26ms/step - loss: 0.0286 - mean_absolute_error: 0.0961 - val_loss: 0.0282 - val_mean_absolute_error: 0.0947
# Epoch 5/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0282 - mean_absolute_error: 0.0955 - val_loss: 0.0280 - val_mean_absolute_error: 0.0938
# Epoch 6/50
# 135/135 [==============================] - 4s 26ms/step - loss: 0.0280 - mean_absolute_error: 0.0946 - val_loss: 0.0277 - val_mean_absolute_error: 0.0928
# Epoch 7/50
# 135/135 [==============================] - 4s 26ms/step - loss: 0.0278 - mean_absolute_error: 0.0944 - val_loss: 0.0277 - val_mean_absolute_error: 0.0924
# Epoch 8/50
# 135/135 [==============================] - 4s 26ms/step - loss: 0.0276 - mean_absolute_error: 0.0939 - val_loss: 0.0273 - val_mean_absolute_error: 0.0931
# Epoch 9/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0273 - mean_absolute_error: 0.0932 - val_loss: 0.0274 - val_mean_absolute_error: 0.0919
# Epoch 10/50
# 135/135 [==============================] - 4s 26ms/step - loss: 0.0272 - mean_absolute_error: 0.0927 - val_loss: 0.0268 - val_mean_absolute_error: 0.0926
# Epoch 11/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0269 - mean_absolute_error: 0.0923 - val_loss: 0.0266 - val_mean_absolute_error: 0.0934
# Epoch 12/50
# 135/135 [==============================] - 4s 26ms/step - loss: 0.0268 - mean_absolute_error: 0.0920 - val_loss: 0.0265 - val_mean_absolute_error: 0.0935
# Epoch 13/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0266 - mean_absolute_error: 0.0914 - val_loss: 0.0264 - val_mean_absolute_error: 0.0926
# Epoch 14/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0265 - mean_absolute_error: 0.0912 - val_loss: 0.0263 - val_mean_absolute_error: 0.0922
# Epoch 15/50
# 135/135 [==============================] - 4s 26ms/step - loss: 0.0264 - mean_absolute_error: 0.0908 - val_loss: 0.0260 - val_mean_absolute_error: 0.0927
# Epoch 16/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0263 - mean_absolute_error: 0.0904 - val_loss: 0.0259 - val_mean_absolute_error: 0.0927
# Epoch 17/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0262 - mean_absolute_error: 0.0902 - val_loss: 0.0256 - val_mean_absolute_error: 0.0922
# Epoch 18/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0260 - mean_absolute_error: 0.0897 - val_loss: 0.0257 - val_mean_absolute_error: 0.0904
# Epoch 19/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0259 - mean_absolute_error: 0.0892 - val_loss: 0.0256 - val_mean_absolute_error: 0.0917
# Epoch 20/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0257 - mean_absolute_error: 0.0892 - val_loss: 0.0253 - val_mean_absolute_error: 0.0901
# Epoch 21/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0257 - mean_absolute_error: 0.0890 - val_loss: 0.0253 - val_mean_absolute_error: 0.0897
# Epoch 22/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0256 - mean_absolute_error: 0.0885 - val_loss: 0.0253 - val_mean_absolute_error: 0.0902
# Epoch 23/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0256 - mean_absolute_error: 0.0886 - val_loss: 0.0251 - val_mean_absolute_error: 0.0904
# Epoch 24/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0254 - mean_absolute_error: 0.0880 - val_loss: 0.0249 - val_mean_absolute_error: 0.0910
# Epoch 25/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0253 - mean_absolute_error: 0.0877 - val_loss: 0.0249 - val_mean_absolute_error: 0.0908
# Epoch 26/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0252 - mean_absolute_error: 0.0876 - val_loss: 0.0249 - val_mean_absolute_error: 0.0885
# Epoch 27/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0251 - mean_absolute_error: 0.0873 - val_loss: 0.0246 - val_mean_absolute_error: 0.0897
# Epoch 28/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0251 - mean_absolute_error: 0.0872 - val_loss: 0.0248 - val_mean_absolute_error: 0.0887
# Epoch 29/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0249 - mean_absolute_error: 0.0868 - val_loss: 0.0245 - val_mean_absolute_error: 0.0883
# Epoch 30/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0249 - mean_absolute_error: 0.0868 - val_loss: 0.0245 - val_mean_absolute_error: 0.0873
# Epoch 31/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0249 - mean_absolute_error: 0.0864 - val_loss: 0.0245 - val_mean_absolute_error: 0.0896
# Epoch 32/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0248 - mean_absolute_error: 0.0863 - val_loss: 0.0244 - val_mean_absolute_error: 0.0892
# Epoch 33/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0247 - mean_absolute_error: 0.0863 - val_loss: 0.0244 - val_mean_absolute_error: 0.0885
# Epoch 34/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0247 - mean_absolute_error: 0.0860 - val_loss: 0.0248 - val_mean_absolute_error: 0.0878
# Epoch 35/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0245 - mean_absolute_error: 0.0860 - val_loss: 0.0240 - val_mean_absolute_error: 0.0893
# Epoch 36/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0245 - mean_absolute_error: 0.0856 - val_loss: 0.0241 - val_mean_absolute_error: 0.0883
# Epoch 37/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0245 - mean_absolute_error: 0.0856 - val_loss: 0.0242 - val_mean_absolute_error: 0.0889
# Epoch 38/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0243 - mean_absolute_error: 0.0853 - val_loss: 0.0240 - val_mean_absolute_error: 0.0876
# Epoch 39/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0243 - mean_absolute_error: 0.0850 - val_loss: 0.0240 - val_mean_absolute_error: 0.0880
# Epoch 40/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0242 - mean_absolute_error: 0.0850 - val_loss: 0.0242 - val_mean_absolute_error: 0.0857
# Epoch 41/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0241 - mean_absolute_error: 0.0846 - val_loss: 0.0238 - val_mean_absolute_error: 0.0881
# Epoch 42/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0241 - mean_absolute_error: 0.0846 - val_loss: 0.0238 - val_mean_absolute_error: 0.0870
# Epoch 43/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0241 - mean_absolute_error: 0.0844 - val_loss: 0.0240 - val_mean_absolute_error: 0.0855
# Epoch 44/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0240 - mean_absolute_error: 0.0843 - val_loss: 0.0238 - val_mean_absolute_error: 0.0878
# Epoch 45/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0240 - mean_absolute_error: 0.0842 - val_loss: 0.0238 - val_mean_absolute_error: 0.0876
# Epoch 46/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0240 - mean_absolute_error: 0.0843 - val_loss: 0.0237 - val_mean_absolute_error: 0.0867
# Epoch 47/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0238 - mean_absolute_error: 0.0839 - val_loss: 0.0237 - val_mean_absolute_error: 0.0865
# Epoch 48/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0239 - mean_absolute_error: 0.0838 - val_loss: 0.0236 - val_mean_absolute_error: 0.0860
# Epoch 49/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0237 - mean_absolute_error: 0.0836 - val_loss: 0.0235 - val_mean_absolute_error: 0.0872
# Epoch 50/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0237 - mean_absolute_error: 0.0833 - val_loss: 0.0236 - val_mean_absolute_error: 0.0862
# Epoch 1/50
# 135/135 [==============================] - 5s 32ms/step - loss: 0.0354 - mean_absolute_error: 0.1009 - val_loss: 0.0315 - val_mean_absolute_error: 0.0931
# Epoch 2/50
# 135/135 [==============================] - 3s 23ms/step - loss: 0.0324 - mean_absolute_error: 0.0979 - val_loss: 0.0319 - val_mean_absolute_error: 0.0927
# Epoch 3/50
# 135/135 [==============================] - 3s 23ms/step - loss: 0.0317 - mean_absolute_error: 0.0980 - val_loss: 0.0324 - val_mean_absolute_error: 0.0931
# Epoch 4/50
# 135/135 [==============================] - 3s 23ms/step - loss: 0.0312 - mean_absolute_error: 0.0983 - val_loss: 0.0324 - val_mean_absolute_error: 0.0945
# Epoch 5/50
# 135/135 [==============================] - 3s 23ms/step - loss: 0.0308 - mean_absolute_error: 0.0983 - val_loss: 0.0326 - val_mean_absolute_error: 0.0970
# Epoch 6/50
# 133/135 [============================>.] - ETA: 0s - loss: 0.0307 - mean_absolute_error: 0.0988Restoring model weights from the end of the best epoch: 1.
# 135/135 [==============================] - 3s 23ms/step - loss: 0.0308 - mean_absolute_error: 0.0988 - val_loss: 0.0322 - val_mean_absolute_error: 0.0981
# Epoch 6: early stopping
# Epoch 1/50
# 135/135 [==============================] - 6s 36ms/step - loss: 0.0314 - mean_absolute_error: 0.0976 - val_loss: 0.0296 - val_mean_absolute_error: 0.0972
# Epoch 2/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0297 - mean_absolute_error: 0.0971 - val_loss: 0.0288 - val_mean_absolute_error: 0.0964
# Epoch 3/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0289 - mean_absolute_error: 0.0962 - val_loss: 0.0285 - val_mean_absolute_error: 0.0963
# Epoch 4/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0285 - mean_absolute_error: 0.0955 - val_loss: 0.0283 - val_mean_absolute_error: 0.0953
# Epoch 5/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0280 - mean_absolute_error: 0.0949 - val_loss: 0.0279 - val_mean_absolute_error: 0.0937
# Epoch 6/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0278 - mean_absolute_error: 0.0941 - val_loss: 0.0277 - val_mean_absolute_error: 0.0938
# Epoch 7/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0276 - mean_absolute_error: 0.0935 - val_loss: 0.0272 - val_mean_absolute_error: 0.0947
# Epoch 8/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0273 - mean_absolute_error: 0.0930 - val_loss: 0.0275 - val_mean_absolute_error: 0.0920
# Epoch 9/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0272 - mean_absolute_error: 0.0927 - val_loss: 0.0271 - val_mean_absolute_error: 0.0923
# Epoch 10/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0269 - mean_absolute_error: 0.0919 - val_loss: 0.0269 - val_mean_absolute_error: 0.0921
# Epoch 11/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0268 - mean_absolute_error: 0.0916 - val_loss: 0.0265 - val_mean_absolute_error: 0.0923
# Epoch 12/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0266 - mean_absolute_error: 0.0912 - val_loss: 0.0268 - val_mean_absolute_error: 0.0907
# Epoch 13/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0265 - mean_absolute_error: 0.0907 - val_loss: 0.0264 - val_mean_absolute_error: 0.0922
# Epoch 14/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0264 - mean_absolute_error: 0.0904 - val_loss: 0.0263 - val_mean_absolute_error: 0.0905
# Epoch 15/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0262 - mean_absolute_error: 0.0900 - val_loss: 0.0260 - val_mean_absolute_error: 0.0920
# Epoch 16/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0260 - mean_absolute_error: 0.0894 - val_loss: 0.0261 - val_mean_absolute_error: 0.0902
# Epoch 17/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0259 - mean_absolute_error: 0.0891 - val_loss: 0.0256 - val_mean_absolute_error: 0.0925
# Epoch 18/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0258 - mean_absolute_error: 0.0891 - val_loss: 0.0256 - val_mean_absolute_error: 0.0907
# Epoch 19/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0257 - mean_absolute_error: 0.0884 - val_loss: 0.0255 - val_mean_absolute_error: 0.0905
# Epoch 20/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0256 - mean_absolute_error: 0.0884 - val_loss: 0.0254 - val_mean_absolute_error: 0.0902
# Epoch 21/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0254 - mean_absolute_error: 0.0880 - val_loss: 0.0251 - val_mean_absolute_error: 0.0911
# Epoch 22/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0254 - mean_absolute_error: 0.0878 - val_loss: 0.0250 - val_mean_absolute_error: 0.0909
# Epoch 23/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0252 - mean_absolute_error: 0.0874 - val_loss: 0.0252 - val_mean_absolute_error: 0.0904
# Epoch 24/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0252 - mean_absolute_error: 0.0873 - val_loss: 0.0249 - val_mean_absolute_error: 0.0894
# Epoch 25/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0250 - mean_absolute_error: 0.0867 - val_loss: 0.0249 - val_mean_absolute_error: 0.0898
# Epoch 26/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0250 - mean_absolute_error: 0.0868 - val_loss: 0.0248 - val_mean_absolute_error: 0.0890
# Epoch 27/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0248 - mean_absolute_error: 0.0862 - val_loss: 0.0246 - val_mean_absolute_error: 0.0895
# Epoch 28/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0248 - mean_absolute_error: 0.0861 - val_loss: 0.0244 - val_mean_absolute_error: 0.0887
# Epoch 29/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0247 - mean_absolute_error: 0.0859 - val_loss: 0.0246 - val_mean_absolute_error: 0.0868
# Epoch 30/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0247 - mean_absolute_error: 0.0858 - val_loss: 0.0244 - val_mean_absolute_error: 0.0889
# Epoch 31/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0246 - mean_absolute_error: 0.0854 - val_loss: 0.0243 - val_mean_absolute_error: 0.0901
# Epoch 32/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0245 - mean_absolute_error: 0.0857 - val_loss: 0.0245 - val_mean_absolute_error: 0.0870
# Epoch 33/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0244 - mean_absolute_error: 0.0851 - val_loss: 0.0243 - val_mean_absolute_error: 0.0891
# Epoch 34/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0244 - mean_absolute_error: 0.0853 - val_loss: 0.0242 - val_mean_absolute_error: 0.0881
# Epoch 35/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0243 - mean_absolute_error: 0.0849 - val_loss: 0.0242 - val_mean_absolute_error: 0.0870
# Epoch 36/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0241 - mean_absolute_error: 0.0845 - val_loss: 0.0240 - val_mean_absolute_error: 0.0884
# Epoch 37/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0241 - mean_absolute_error: 0.0845 - val_loss: 0.0239 - val_mean_absolute_error: 0.0885
# Epoch 38/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0241 - mean_absolute_error: 0.0846 - val_loss: 0.0240 - val_mean_absolute_error: 0.0872
# Epoch 39/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0240 - mean_absolute_error: 0.0841 - val_loss: 0.0238 - val_mean_absolute_error: 0.0885
# Epoch 40/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0239 - mean_absolute_error: 0.0840 - val_loss: 0.0239 - val_mean_absolute_error: 0.0866
# Epoch 41/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0239 - mean_absolute_error: 0.0838 - val_loss: 0.0238 - val_mean_absolute_error: 0.0858
# Epoch 42/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0239 - mean_absolute_error: 0.0837 - val_loss: 0.0238 - val_mean_absolute_error: 0.0862
# Epoch 43/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0237 - mean_absolute_error: 0.0834 - val_loss: 0.0237 - val_mean_absolute_error: 0.0862
# Epoch 44/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0238 - mean_absolute_error: 0.0833 - val_loss: 0.0236 - val_mean_absolute_error: 0.0883
# Epoch 45/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0237 - mean_absolute_error: 0.0833 - val_loss: 0.0236 - val_mean_absolute_error: 0.0866
# Epoch 46/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0237 - mean_absolute_error: 0.0832 - val_loss: 0.0236 - val_mean_absolute_error: 0.0865
# Epoch 47/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0236 - mean_absolute_error: 0.0830 - val_loss: 0.0236 - val_mean_absolute_error: 0.0871
# Epoch 48/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0235 - mean_absolute_error: 0.0826 - val_loss: 0.0235 - val_mean_absolute_error: 0.0866
# Epoch 49/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0235 - mean_absolute_error: 0.0827 - val_loss: 0.0234 - val_mean_absolute_error: 0.0866
# Epoch 50/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0234 - mean_absolute_error: 0.0824 - val_loss: 0.0234 - val_mean_absolute_error: 0.0872
# Epoch 1/50
# 135/135 [==============================] - 5s 32ms/step - loss: 0.0353 - mean_absolute_error: 0.1012 - val_loss: 0.0318 - val_mean_absolute_error: 0.0923
# Epoch 2/50
# 135/135 [==============================] - 3s 23ms/step - loss: 0.0324 - mean_absolute_error: 0.0982 - val_loss: 0.0328 - val_mean_absolute_error: 0.0920
# Epoch 3/50
# 135/135 [==============================] - 3s 23ms/step - loss: 0.0316 - mean_absolute_error: 0.0985 - val_loss: 0.0330 - val_mean_absolute_error: 0.0921
# Epoch 4/50
# 135/135 [==============================] - 3s 23ms/step - loss: 0.0311 - mean_absolute_error: 0.0985 - val_loss: 0.0328 - val_mean_absolute_error: 0.0929
# Epoch 5/50
# 135/135 [==============================] - 3s 23ms/step - loss: 0.0309 - mean_absolute_error: 0.0988 - val_loss: 0.0324 - val_mean_absolute_error: 0.0953
# Epoch 6/50
# 133/135 [============================>.] - ETA: 0s - loss: 0.0306 - mean_absolute_error: 0.0990Restoring model weights from the end of the best epoch: 1.
# 135/135 [==============================] - 3s 23ms/step - loss: 0.0306 - mean_absolute_error: 0.0990 - val_loss: 0.0326 - val_mean_absolute_error: 0.0956
# Epoch 6: early stopping
# Epoch 1/50
# 135/135 [==============================] - 5s 35ms/step - loss: 0.0314 - mean_absolute_error: 0.0976 - val_loss: 0.0302 - val_mean_absolute_error: 0.0929
# Epoch 2/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0297 - mean_absolute_error: 0.0972 - val_loss: 0.0289 - val_mean_absolute_error: 0.0947
# Epoch 3/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0290 - mean_absolute_error: 0.0964 - val_loss: 0.0287 - val_mean_absolute_error: 0.0946
# Epoch 4/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0285 - mean_absolute_error: 0.0958 - val_loss: 0.0284 - val_mean_absolute_error: 0.0946
# Epoch 5/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0281 - mean_absolute_error: 0.0950 - val_loss: 0.0278 - val_mean_absolute_error: 0.0950
# Epoch 6/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0278 - mean_absolute_error: 0.0946 - val_loss: 0.0280 - val_mean_absolute_error: 0.0929
# Epoch 7/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0275 - mean_absolute_error: 0.0936 - val_loss: 0.0276 - val_mean_absolute_error: 0.0932
# Epoch 8/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0273 - mean_absolute_error: 0.0932 - val_loss: 0.0273 - val_mean_absolute_error: 0.0944
# Epoch 9/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0272 - mean_absolute_error: 0.0928 - val_loss: 0.0269 - val_mean_absolute_error: 0.0922
# Epoch 10/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0270 - mean_absolute_error: 0.0925 - val_loss: 0.0267 - val_mean_absolute_error: 0.0917
# Epoch 11/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0268 - mean_absolute_error: 0.0918 - val_loss: 0.0266 - val_mean_absolute_error: 0.0923
# Epoch 12/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0267 - mean_absolute_error: 0.0916 - val_loss: 0.0268 - val_mean_absolute_error: 0.0907
# Epoch 13/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0265 - mean_absolute_error: 0.0911 - val_loss: 0.0266 - val_mean_absolute_error: 0.0912
# Epoch 14/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0265 - mean_absolute_error: 0.0909 - val_loss: 0.0263 - val_mean_absolute_error: 0.0911
# Epoch 15/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0263 - mean_absolute_error: 0.0905 - val_loss: 0.0260 - val_mean_absolute_error: 0.0913
# Epoch 16/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0263 - mean_absolute_error: 0.0906 - val_loss: 0.0261 - val_mean_absolute_error: 0.0897
# Epoch 17/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0261 - mean_absolute_error: 0.0900 - val_loss: 0.0259 - val_mean_absolute_error: 0.0898
# Epoch 18/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0260 - mean_absolute_error: 0.0897 - val_loss: 0.0257 - val_mean_absolute_error: 0.0895
# Epoch 19/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0258 - mean_absolute_error: 0.0894 - val_loss: 0.0256 - val_mean_absolute_error: 0.0883
# Epoch 20/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0257 - mean_absolute_error: 0.0891 - val_loss: 0.0254 - val_mean_absolute_error: 0.0891
# Epoch 21/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0256 - mean_absolute_error: 0.0887 - val_loss: 0.0253 - val_mean_absolute_error: 0.0899
# Epoch 22/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0254 - mean_absolute_error: 0.0882 - val_loss: 0.0251 - val_mean_absolute_error: 0.0906
# Epoch 23/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0254 - mean_absolute_error: 0.0882 - val_loss: 0.0252 - val_mean_absolute_error: 0.0876
# Epoch 24/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0253 - mean_absolute_error: 0.0879 - val_loss: 0.0249 - val_mean_absolute_error: 0.0886
# Epoch 25/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0252 - mean_absolute_error: 0.0876 - val_loss: 0.0248 - val_mean_absolute_error: 0.0886
# Epoch 26/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0252 - mean_absolute_error: 0.0875 - val_loss: 0.0248 - val_mean_absolute_error: 0.0886
# Epoch 27/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0250 - mean_absolute_error: 0.0873 - val_loss: 0.0246 - val_mean_absolute_error: 0.0884
# Epoch 28/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0250 - mean_absolute_error: 0.0871 - val_loss: 0.0246 - val_mean_absolute_error: 0.0875
# Epoch 29/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0248 - mean_absolute_error: 0.0865 - val_loss: 0.0244 - val_mean_absolute_error: 0.0886
# Epoch 30/50
# 135/135 [==============================] - 4s 26ms/step - loss: 0.0247 - mean_absolute_error: 0.0866 - val_loss: 0.0244 - val_mean_absolute_error: 0.0883
# Epoch 31/50
# 135/135 [==============================] - 3s 26ms/step - loss: 0.0247 - mean_absolute_error: 0.0862 - val_loss: 0.0242 - val_mean_absolute_error: 0.0876
# Epoch 32/50
# 135/135 [==============================] - 4s 26ms/step - loss: 0.0247 - mean_absolute_error: 0.0862 - val_loss: 0.0242 - val_mean_absolute_error: 0.0890
# Epoch 33/50
# 135/135 [==============================] - 4s 26ms/step - loss: 0.0245 - mean_absolute_error: 0.0860 - val_loss: 0.0243 - val_mean_absolute_error: 0.0879
# Epoch 34/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0245 - mean_absolute_error: 0.0859 - val_loss: 0.0242 - val_mean_absolute_error: 0.0874
# Epoch 35/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0244 - mean_absolute_error: 0.0857 - val_loss: 0.0243 - val_mean_absolute_error: 0.0864
# Epoch 36/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0243 - mean_absolute_error: 0.0854 - val_loss: 0.0240 - val_mean_absolute_error: 0.0883
# Epoch 37/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0243 - mean_absolute_error: 0.0854 - val_loss: 0.0239 - val_mean_absolute_error: 0.0877
# Epoch 38/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0242 - mean_absolute_error: 0.0851 - val_loss: 0.0240 - val_mean_absolute_error: 0.0871
# Epoch 39/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0242 - mean_absolute_error: 0.0849 - val_loss: 0.0240 - val_mean_absolute_error: 0.0871
# Epoch 40/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0240 - mean_absolute_error: 0.0847 - val_loss: 0.0240 - val_mean_absolute_error: 0.0860
# Epoch 41/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0240 - mean_absolute_error: 0.0845 - val_loss: 0.0239 - val_mean_absolute_error: 0.0871
# Epoch 42/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0240 - mean_absolute_error: 0.0846 - val_loss: 0.0239 - val_mean_absolute_error: 0.0851
# Epoch 43/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0239 - mean_absolute_error: 0.0842 - val_loss: 0.0237 - val_mean_absolute_error: 0.0864
# Epoch 44/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0239 - mean_absolute_error: 0.0842 - val_loss: 0.0237 - val_mean_absolute_error: 0.0859
# Epoch 45/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0239 - mean_absolute_error: 0.0843 - val_loss: 0.0236 - val_mean_absolute_error: 0.0850
# Epoch 46/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0237 - mean_absolute_error: 0.0837 - val_loss: 0.0236 - val_mean_absolute_error: 0.0861
# Epoch 47/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0237 - mean_absolute_error: 0.0836 - val_loss: 0.0237 - val_mean_absolute_error: 0.0850
# Epoch 48/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0237 - mean_absolute_error: 0.0834 - val_loss: 0.0235 - val_mean_absolute_error: 0.0850
# Epoch 49/50
# 135/135 [==============================] - 4s 27ms/step - loss: 0.0236 - mean_absolute_error: 0.0833 - val_loss: 0.0235 - val_mean_absolute_error: 0.0863
# Epoch 50/50
# 135/135 [==============================] - 4s 26ms/step - loss: 0.0235 - mean_absolute_error: 0.0832 - val_loss: 0.0236 - val_mean_absolute_error: 0.0853
